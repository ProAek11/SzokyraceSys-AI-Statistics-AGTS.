# %% [markdown]
# <a href="https://colab.research.google.com/github/ProAek11/StrategyTradingFrendersis-AI-System/blob/main/Frendersis_AI_Project_Strategy_Trading_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `**Introduction Table of Contents**`

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # **Install Requestments.**

# %% [markdown]
# # **Install Requestments.**

# %%
#pip install
# !pip install gspread oauth2client #Google sheet Package
# !pip install ipywidgets
# !pip install Ipython
# !pip install IPykernel
# !pip install matplotlib
# !pip install numpy
# !pip install requests
# !pip install datetime

# %%
# !pip install pandas
# !pip install pandas-datareader
# !pip install plotly
# !pip install plotly.express
# !pip install plotly-resampler
#!pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 57.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 20.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 76.2 MB/s eta 0:00:00
# ...

# %%
# !pip install yfinance
# !pip install yfinance backtrader
# !pip install yahoo-finance
# !pip install yahoofinancials
# !pip install fix-yahoo-finance
# !pip install yahooquery[premium]
# !pip install yahooquery
# Out:
# ...
# ERROR: Operation cancelled by user
# ...

# %%
# !pip install jupyter
# !pip install jupyterlab
# !pip install jupyter notebook

# %%
# !pip install jupyter-dash

# %% [markdown]
# # **Install Requestments - def Process Package Model.**

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.2 MB/s eta 0:00:00
# ...

# %%
# !pip install pyfolio
# !pip install quantstats --upgrade --no-cache-dir
# !pip install tabulate
# !pip install statsmodels
# !pip install prophet
# !pip install backtesting
# !pip install backtrader
# !pip install statsforecast
# !pip install pytrader
# !pip install tradingview-ta
# !pip install pyzmq
# !pip install --upgrade lean
# !pip install -U vectorbt
# !pip install scipy #iconda env using.
# !pip install seaborn
# !pip install tqdm
# !pip install gdown
# !pip install Scikit-learn
# !pip install Scikit-image
# !pip install PyTorch
# !pip install Datasets
# !pip install XGBoost

# %%
pip install --upgrade quantconnect-stubs
# !pip install quantconnect
# !pip install --upgrade lean

# %%
import quantstats as qs
import yfinance as yf
import tabulate

# %% [markdown]
# # New Section

# %% [markdown]
# # **"Developing & functions to Revise Name yfinance Module Package for Using Request Symbol"**

# %% [markdown]
# # New Section

# %%
""" Report Research Generate by AI-Bard & AI-ChatGPT MSFT ||
    1. Nvidia (NVDA): 1-year return of 239.5%
    2. C3.ai (AI): 1-year return of 121.3%
    3. Cadence Design Systems (CDNS): 1-year return of 74.8%
    4. Synopsys (SNPS): 1-year return of 74.7%
    5. Microsoft (MSFT): 1-year return of 68.2%
1. Nvidia Corporation (NVDA)
2. Alphabet Inc. (GOOGL)
3. Amazon.com, Inc. (AMZN)
4. Microsoft Corporation (MSFT)
5. International Business Machines Corporation (IBM)
6. Advanced Micro Devices, Inc. (AMD)
7. Intel Corporation (INTC)
8. Baidu, Inc. (BIDU)
9. Tencent Holdings Limited (TCEHY)
10. Salesforce.com, Inc. (CRM)
The Best AI Stocks of November 2023
Company (ticker)	1-Year Return
Nvidia (NVDA)	239.5%
C3.ai (AI)	121.3%
Cadence Design Systems (CDNS)	74.8%
Synopsys (SNPS)	74.7%
Microsoft (MSFT)	68.2%
Palo Alto Networks (PANW)	62.2%
KLA (KLAC)	60.6%
Alphabet (GOOGL)	55.5%
UiPath (PATH)	54.7%
Amazon (AMZN)	57.1%
NVIDIA Corporation (NVDA): Known for its graphics processing units (GPUs) used in AI applications.

Alphabet Inc. (GOOGL): The parent company of Google, involved in various AI-related projects and technologies.

Microsoft Corporation (MSFT): Microsoft has been investing heavily in AI, with applications in products like Azure, Microsoft 365, and more.

International Business Machines Corporation (IBM): IBM has been involved in AI research and offers AI-related solutions.

Amazon.com Inc. (AMZN): Through its Amazon Web Services (AWS) platform, Amazon provides cloud services, including AI-related services.

Tesla, Inc. (TSLA): Known for its electric vehicles, Tesla also integrates AI into its autonomous driving technology.

Intel Corporation (INTC): Intel is involved in providing hardware solutions for AI, including processors optimized for AI workloads.

Baidu, Inc. (BIDU): A Chinese company known for its search engine, Baidu has also been investing in AI research and development.

Salesforce.com Inc. (CRM): Salesforce incorporates AI into its customer relationship management (CRM) software.

Twilio Inc. (TWLO): Provides cloud communications platforms and has been incorporating AI into its services."""

# %%
import yfinance as yf
import pandas as pd
import time
import numpy as np
import datetime
import os
import sys

#List All Tickers TotalUsing
#
list_all_symbol = ['list_ai_tech']
#1. SearchHighYield - Group
l_search_high_yield = ['list_ai_tech']
  #1.1 Equity Stock Group
equity_ = ['list_ai_tech']
    #1.2 AI Technology & - Sector # For Investing on Trending.
    #Alphabet Inc. (GOOGL) #NVIDIA Corporation (NVDA)
list_ai_tech2 = ["MSFT", "META", "NVDA", "GOOGL", "AI","AMD", "INTC", "IBM", "BOTZ", "AMZN", "TSLA"]
list_ai_tech = ['MSFT', 'META', 'NVDIA','GOOGL', 'AI','AMD', 'INTC', 'IBM', 'BOTZ', 'AMZN', 'TSLA']


ListType_ = {}
#-------------------------------------------------------------------
#2. Safe Haven Defensive
l_safehaven_d = ['']

#-------------------------------------------------------------------

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "SPY AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f3c827cfeb4c> in <cell line: 1>()
# ----> 1 data = yf.download(  # or pdr.get_data_yahoo(...
#       2         # tickers list or string as well
#       3         tickers = "SPY AAPL MSFT",
#       4
#       5         # use "period" instead of start/end
#
# NameError: name 'yf' is not defined

# %% [markdown]
# # New Section

# %%
# !pip install yahooquery[premium]
# !pip install yahooquery

# %%
data
# Out:
#                   MSFT                                                \
#                   Open        High         Low       Close    Volume
# Date
# 2023-01-03  240.943573  243.590105  235.313487  237.474335  25740000
# 2023-01-04  230.238500  230.823311  223.974054  227.086456  50623400
# 2023-01-05  225.203131  225.550061  219.810941  220.356110  39585600
# 2023-01-06  221.040064  223.775801  217.422150  222.953094  43613600
# 2023-01-09  224.459731  229.207640  224.420089  225.123840  27369800
# ...                ...         ...         ...         ...       ...
# 2023-11-15  371.279999  373.130005  367.109985  369.670013  26860100
# 2023-11-16  370.959991  376.350006  370.179993  376.170013  27182300
# 2023-11-17  373.609985  374.369995  367.000000  369.850006  40157000
# 2023-11-20  371.220001  378.869995  371.000000  377.440002  52465100
# 2023-11-21  375.670013  376.221497  371.119995  372.489990  20737321
#
# ...

# %%
from get_all_tickers import get_tickers as gt

list_of_tickers = gt.get_tickers()
# or if you want to save them to a CSV file
get.save_tickers()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-39-be263ad4829e> in <cell line: 3>()
#       1 from get_all_tickers import get_tickers as gt
#       2
# ----> 3 list_of_tickers = gt.get_tickers()
#       4 # or if you want to save them to a CSV file
#       5 get.save_tickers()
#
# /usr/local/lib/python3.10/dist-packages/get_all_tickers/get_tickers.py in get_tickers(NYSE, NASDAQ, AMEX)
#      71     tickers_list = []
#      72     if NYSE:
# ---> 73         tickers_list.extend(__exchange2list('nyse'))
#      74     if NASDAQ:
#      75         tickers_list.extend(__exchange2list('nasdaq'))
#
# /usr/local/lib/python3.10/dist-packages/get_all_tickers/get_tickers.py in __exchange2list(exchange)
#     136
#     137 def __exchange2list(exchange):
# --> 138     df = __exchange2df(exchange)
#     139     # removes weird tickers
# ...

# %%
get_tickers(NYSE=True, NASDAQ=True, AMEX=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f16e610c67ca> in <cell line: 1>()
# ----> 1 get_tickers(NYSE=True, NASDAQ=True, AMEX=True)
#
# NameError: name 'get_tickers' is not defined

# %%
#CBOE Interest Rate 10 Year T No (^TNX)
#Revised names symbol
class f_rename_symbol(a,b):
    def f_rename(A,B):

      BTCUSD = BTC-USD
      CrudeOil = CL=F
      DOWJONES = YM=F
      NASDAQ = NQ=F
      SP500 = ES=F
      USDX = DX=F
      US10Y = ^TNX
      GOLD = GC=F
      EURUSD = EURUSD=X
      VIX = ^VIX
      USDJPY = JPY=X
      GBPUSD = GBPUSD=X
      AUDUSD = AUDUSD=X
      NZDUSD = NZDUSD=X
      USDCAD = USDCAD=X
      GBPJPY = GBPJPY=X

      BTCUSD = BTC-USD
CrudeOil = CL=F
DOWJONES = YM=F
NASDAQ = NQ=F
SP500 = ES=F
USDX = DX=F
US10Y = ^TNX
GOLD = GC=F
EURUSD = EURUSD=X
      VIX = ^VIX
      USDJPY = JPY=X
      GBPUSD = GBPUSD=X
      AUDUSD = AUDUSD=X
      NZDUSD = NZDUSD=X
      USDCAD = USDCAD=X
      GBPJPY = GBPJPY=X
# Out:
#   File "<ipython-input-3-080539d08fa8>", line 11
#     US10Y = ^TNX
#             ^
# SyntaxError: invalid syntax

# %%
#

# %% [markdown]
# # ***Algorithm & Logical Criteria of Strategy Trading to Decision Trade Entry.***

# %%
class

# %% [markdown]
# # ***Build Database Structure ***

# %% [markdown]
# # New Section

# %% [markdown]
# # ***Optimizations Multi-Timeframe***
# #https://www.qmr.ai/yfinance-library-the-definitive-guide/

# %%
# !pip install yfinance
# !pip install yahooquery
# !pip install datetime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 40.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# bigframes 0.16.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.1.4 which is incompatible.
# ...

# %%
# IMPORT THE LIBRARY
import yfinance as yf
from datetime import datetime

# CREATE TICKER INSTANCE FOR AMAZON
amzn = yf.Ticker("AMZN")

# GET TODAYS DATE AND CONVERT IT TO A STRING WITH YYYY-MM-DD FORMAT (YFINANCE EXPECTS THAT FORMAT)
end_date = datetime.now().strftime('%Y-%m-%d')
amzn_hist = amzn.history(start='2022-01-01',end=end_date)
print(amzn_hist)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-01-03 00:00:00-05:00  167.550003  170.703506  166.160507  170.404495
# 2022-01-04 00:00:00-05:00  170.438004  171.399994  166.349503  167.522003
# 2022-01-05 00:00:00-05:00  166.882996  167.126495  164.356995  164.356995
# 2022-01-06 00:00:00-05:00  163.450500  164.800003  161.936996  163.253998
# 2022-01-07 00:00:00-05:00  163.839005  165.243500  162.031006  162.554001
# ...                               ...         ...         ...         ...
# 2023-12-08 00:00:00-05:00  145.479996  147.839996  145.399994  147.419998
# 2023-12-11 00:00:00-05:00  145.660004  146.190002  143.639999  145.889999
# 2023-12-12 00:00:00-05:00  145.520004  147.500000  145.300003  147.479996
# 2023-12-13 00:00:00-05:00  148.119995  149.460007  146.820007  148.839996
# 2023-12-14 00:00:00-05:00  149.929993  150.539993  145.520004  147.419998
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
# GETTING THE MAX AMOUNT OF RECENT 1 MINUTE DATA.
# OBSERVATION: THE VARIABLE 'end_date' WAS DECLARED IN THE PREVIOUS CODE SNIPPED
amzn_hist = amzn.history(period='max',end=end_date,interval='1m')

# %%
companies = ['AMZN','GOOG','WMT','TSLA','META']
tickers = yf.Tickers(companies)
tickers_hist = tickers.history(period='max',end=end_date,interval='1m',)
tickers_hist
# Out:
# [*********************100%%**********************]  5 of 5 completed
#                                 Close                                      \
#                                  AMZN        GOOG        META        TSLA
# Datetime
# 2023-12-08 09:30:00-05:00  145.949997  136.247696  325.239990  240.130005
# 2023-12-08 09:31:00-05:00  145.759995  136.502197  325.184998  239.719894
# 2023-12-08 09:32:00-05:00  145.860001  136.770004  324.762909  241.380005
# 2023-12-08 09:33:00-05:00  145.699997  136.490005  324.989990  241.470001
# 2023-12-08 09:34:00-05:00  145.529999  136.279999  324.927002  241.200500
# ...                               ...         ...         ...         ...
# 2023-12-14 15:55:00-05:00  147.192001  133.065002  333.220001  250.559998
# 2023-12-14 15:56:00-05:00  147.115005  132.945007  332.828400  250.169998
# 2023-12-14 15:57:00-05:00  147.287796  133.054993  332.970001  250.589996
# 2023-12-14 15:58:00-05:00  147.285004  133.100006  333.040009  250.809906
# ...

# %%
# TRANSFORM MULTI-LEVEL INDEX INTO A SINGLE-INDEX SET OF COLUMNS.
tickers_hist.stack(level=1).rename_axis(['Date', 'Ticker']).reset_index(level=1)
# Out:
#                           Ticker       Close  Dividends        High  \
# Date
# 2023-12-08 09:30:00-05:00   AMZN  145.949997        0.0  146.000000
# 2023-12-08 09:30:00-05:00   GOOG  136.247696        0.0  136.259995
# 2023-12-08 09:30:00-05:00   META  325.239990        0.0  325.390015
# 2023-12-08 09:30:00-05:00   TSLA  240.130005        0.0  240.380005
# 2023-12-08 09:30:00-05:00    WMT  151.929993        0.0  152.080002
# ...                          ...         ...        ...         ...
# 2023-12-14 15:59:00-05:00   AMZN  147.440002        0.0  147.460007
# 2023-12-14 15:59:00-05:00   GOOG  133.220001        0.0  133.240005
# 2023-12-14 15:59:00-05:00   META  333.250000        0.0  333.369995
# 2023-12-14 15:59:00-05:00   TSLA  251.140106        0.0  251.190002
# 2023-12-14 15:59:00-05:00    WMT  152.149994        0.0  152.169998
#
#                                   Low        Open  Stock Splits   Volume
# Date
# ...

# %%
# THIS CODE SNIPPET SAVES THE ENTIRE DATAFRAME IN A CSV FILE
tickers_hist.to_csv('all_data.csv')

# %%
# !pip install yfinance

# %%
import yfinance as yf

# CREATE A TICKER INSTANCE PASSING TESLA AS THE TARGET COMPANY
tsla = yf.Ticker('TSLA')

# CALL THE MULTIPLE FUNCTIONS AVAILABLE AND STORE THEM IN VARIABLES.
actions = tsla.get_actions()
#analysis = tsla.get_analysis()
balance = tsla.get_balance_sheet()
calendar = tsla.get_calendar()
cf = tsla.get_cashflow()
info = tsla.get_info()
inst_holders = tsla.get_institutional_holders()
news = tsla.get_news()
recommendations = tsla.get_recommendations()
sustainability = tsla.get_sustainability()

# PRINT THE RESULTS
print(actions)
print('*'*20)
print(analysis)
print('*'*20)
print(balance)
print('*'*20)
print(calendar)
print('*'*20)
print(cf)
print('*'*20)
print(info)
print('*'*20)
print(inst_holders)
print('*'*20)
print(news)
print('*'*20)
print(recommendations)
print('*'*20)
print(sustainability)
print('*'*20)
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# <ipython-input-9-5eaa9ac531f3> in <cell line: 10>()
#       8 #analysis = tsla.get_analysis()
#       9 balance = tsla.get_balance_sheet()
# ---> 10 calendar = tsla.get_calendar()
#      11 cf = tsla.get_cashflow()
#      12 info = tsla.get_info()
#
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py in get_calendar(self, proxy, as_dict)
#    1704     def get_calendar(self, proxy=None, as_dict=False):
#    1705         self._quote.proxy = proxy
# -> 1706         data = self._quote.calendar
#    1707         if as_dict:
#    1708             return data.to_dict()
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/quote.py in calendar(self)
#     590     def calendar(self) -> pd.DataFrame:
#     591         if self._calendar is None:
# --> 592             raise YFNotImplementedError('calendar')
# ...

# %%
# IMPORT REQUIRED LIBRARY
import yfinance as yf

# CREATE A TICKER INSTANCE FOR TESLA
tsla = yf.Ticker('TSLA')

# FETCH OPTIONS CHAIN DATA FOR THE COMPANY
tsla_options = tsla.option_chain()

# ACCESS BOTH THE CALLS AND PUTS AND STORE THEM IN THEIR RESPECTIVE VARIABLES
tsla_puts = tsla_options.puts
tsla_calls = tsla_options.calls

# %%
# !pip install finplot

# %%
# IMPORT REQUIRED LIBRARIES
# YOU SHOULD MAKE SURE THAT YOU ALREADY INSTLALED THEM PREVIOUSLY
import yfinance as yf
import finplot as fplt

# CREATE A TICKER INSTANCE FOR TESLA
tsla = yf.Ticker('TSLA')

# RETRIEVE 1 YEAR WORTH OF DAILY DATA OF TESLA
df = tsla.history(interval='1d',period='1y')

# PLOT THE OHLC CANDLE CHART
fplt.candlestick_ochl(df[['Open','Close','High','Low']])
fplt.show()

# %%
import yfinance as yf
import finplot as fplt

tsla = yf.Ticker('TSLA')
df = tsla.history(interval='15m',period='60d')
print(df)

# %%
# !pip install pandas

# %%
import pandas as pd
df_45min = df.groupby(pd.Grouper(freq='45Min')).agg({"Open": "first",
                                             "High": "max",
                                             "Low": "min",
                                             "Close": "min",
                                             "Volume": "sum"})

# %% [markdown]
# # ***Python Web Scraping***
