# %% [markdown]
# <a href="https://colab.research.google.com/github/ProAek11/StrategyTradingFrendersis-AI-System/blob/main/Copy_of_Lean_cloud_basicAlgo_python_shared___copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.12-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://cdn.quantconnect.com/miniconda/Miniconda3-4.5.12-Linux-x86_64.sh
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# rm -rf Miniconda3-4.5.12-Linux-x86_64.sh
# Out:
# PREFIX=/usr/local
# reinstalling: python-3.7.1-h0371630_7 ...
# Python 3.7.1
# reinstalling: ca-certificates-2018.03.07-0 ...
# reinstalling: conda-env-2.6.0-1 ...
# reinstalling: libgcc-ng-8.2.0-hdf63c60_1 ...
# reinstalling: libstdcxx-ng-8.2.0-hdf63c60_1 ...
# reinstalling: libffi-3.2.1-hd88cf55_4 ...
# reinstalling: ncurses-6.1-he6710b0_1 ...
# reinstalling: openssl-1.1.1a-h7b6447c_0 ...
# reinstalling: xz-5.2.4-h14c3975_4 ...
# reinstalling: yaml-0.1.7-had09818_2 ...
# reinstalling: zlib-1.2.11-h7b6447c_3 ...
# reinstalling: libedit-3.1.20170329-h6b74fdf_2 ...
# reinstalling: readline-7.0-h7b6447c_5 ...
# reinstalling: tk-8.6.8-hbc83047_0 ...
# reinstalling: sqlite-3.26.0-h7b6447c_0 ...
# reinstalling: asn1crypto-0.24.0-py37_0 ...
# reinstalling: certifi-2018.11.29-py37_0 ...
# reinstalling: chardet-3.0.4-py37_1 ...
# reinstalling: idna-2.8-py37_0 ...
# reinstalling: pycosat-0.6.3-py37h14c3975_0 ...
# reinstalling: pycparser-2.19-py37_0 ...
# ...

# %%
# !conda update -y python conda pip
# Out:
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - pip
#     - python
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     chardet-4.0.0              |py39h06a4308_1003         198 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     pip-21.1.3                 |   py39h06a4308_0         2.0 MB
#     openssl-1.1.1k             |       h27cfd23_0         3.8 MB
#     ca-certificates-2021.7.5   |       h06a4308_1         119 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     ruamel_yaml-0.15.100       |   py39h27cfd23_0         268 KB
#     urllib3-1.26.6             |     pyhd3eb1b0_1         106 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     yaml-0.2.5                 |       h7b6447c_0          87 KB
# ...

# %% [markdown]
# # step 2 : Create a new Python environment with the needed dependencies

# %%
# !conda create -n qc_lean python=3.6.8 cython=0.29.11 pandas=0.25.3 wrapt=1.11.2
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/qc_lean
#
#   added / updated specs:
#     - cython=0.29.11
#     - pandas=0.25.3
#     - python=3.6.8
#     - wrapt=1.11.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            1_gnu          22 KB
#     blas-1.0                   |              mkl           6 KB
#     certifi-2021.5.30          |   py36h06a4308_0         139 KB
#     cython-0.29.11             |   py36he6710b0_0         2.0 MB
#     intel-openmp-2021.2.0      |     h06a4308_610         1.3 MB
#     libedit-3.1.20210216       |       h27cfd23_1         167 KB
#     libffi-3.2.1               |    hf484d3e_1007          48 KB
#     libgcc-ng-9.3.0            |      h5101ec6_17         4.8 MB
# ...

# %%
# %%shell
#
# eval "$(conda shell.bash hook)"
# conda activate qc_lean

# %% [markdown]
# # step 3 : Set PYTHONNET_PYDLL environment variable to location of your python dll in your
#
# installation directory (e.g. /home/{your_user_name}/miniconda3/envs/qc_lean/lib/libpython3.6m.so):
# in case colab it will be usr/local/envs/qc_lean/lib/libpython3.6m.so.1 ( libpython3.6m.so there isn't such file  )
#
# Open /etc/environment with a text editor of your choice.
#
#  Add a new line to the file containing
#  PYTHONNET_PYDLL="/home/{your_user_name}/miniconda3/envs/qc_lean/lib/libpython3.6m.so"
#
#  in case colab : PYTHONNET_PYDLL="/usr/local/envs/qc_lean/lib/libpython3.6m.so.1"
#
#  ( make sure that /usr/local/envs/qc_lean/lib/libpython3.6m.so.1 exists beforehand )
#
#
# #restart runtime

# %%
cd ..
# Out:
# /

# %%
cd tmp
# Out:
# /tmp

# %%
# !wget -q https://packages.microsoft.com/config/ubuntu/18.04/packages-microsoft-prod.deb

# %%
from IPython.display import clear_output
# !sudo apt-get install ./packages-microsoft-prod.deb
clear_output(wait=True)
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'packages-microsoft-prod' instead of './packages-microsoft-prod.deb'
# The following NEW packages will be installed:
#   packages-microsoft-prod
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 0 B/3,132 B of archives.
# After this operation, 43.0 kB of additional disk space will be used.
# Get:1 /tmp/packages-microsoft-prod.deb packages-microsoft-prod all 1.0-ubuntu18.04.2 [3,132 B]
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
from IPython.display import clear_output
# !sudo apt-get update && \
  sudo apt-get install -y aspnetcore-runtime-5.0 && \
  sudo apt-get install -y dotnet-sdk-5.0
clear_output(wait=True)
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:7 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:8 https://packages.microsoft.com/ubuntu/18.04/prod bionic InRelease [4,002 B]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:12 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,780 kB]
# ...

# %%
# !dotnet --version
#output should be -> =5.0.301
# Out:
# =5.0.301

# %%
cd ../content/
# Out:
# /content

# %%
# Install QuantConnect Lean
from IPython.display import clear_output
# !git clone https://github.com/QuantConnect/Lean.git
clear_output(wait=True)
# Out:
# Cloning into 'Lean'...
# remote: Enumerating objects: 102302, done.
# remote: Counting objects: 100% (1301/1301), done.
# remote: Compressing objects: 100% (721/721), done.
# remote: Total 102302 (delta 724), reused 1031 (delta 579), pack-reused 101001
# Receiving objects: 100% (102302/102302), 501.82 MiB | 27.90 MiB/s, done.
# Resolving deltas: 100% (79142/79142), done.
# Checking out files: 100% (4042/4042), done.

# %%
cd Lean
# Out:
# /content/Lean

# %%
from IPython.display import clear_output
# !dotnet build QuantConnect.Lean.sln
clear_output(wait=True )
# Out:
# =
# Welcome to .NET 5.0!
# ---------------------
# SDK Version: 5.0.301
#
# Telemetry
# ---------
# The .NET tools collect usage data in order to help us improve your experience. It is collected by Microsoft and shared with the community. You can opt-out of telemetry by setting the DOTNET_CLI_TELEMETRY_OPTOUT environment variable to '1' or 'true' using your favorite shell.
#
# Read more about .NET CLI Tools telemetry: https://aka.ms/dotnet-cli-telemetry
#
# ----------------
# Installed an ASP.NET Core HTTPS development certificate.
# To trust the certificate run 'dotnet dev-certs https --trust' (Windows and macOS only).
# Learn about HTTPS: https://aka.ms/dotnet-https
# ----------------
# Write your first app: https://aka.ms/dotnet-hello-world
# Find out what's new: https://aka.ms/dotnet-whats-new
# Explore documentation: https://aka.ms/dotnet-docs
# Report issues and find source on GitHub: https://github.com/dotnet/core
# ...

# %%
cd Launcher/bin/Debug/
# Out:
# /content/Lean/Launcher/bin/Debug

# %%
# !dotnet QuantConnect.Lean.Launcher.dll
#output should be like always after backtest
# Out:
# =20210709 13:32:18.498 TRACE:: Config.GetValue(): debug-mode - Using default value: False
# 20210709 13:32:18.507 TRACE:: Config.Get(): Configuration key not found. Key: results-destination-folder - Using default value:
# 20210709 13:32:18.508 TRACE:: Config.Get(): Configuration key not found. Key: plugin-directory - Using default value:
# 20210709 13:32:18.511 TRACE:: Config.Get(): Configuration key not found. Key: composer-dll-directory - Using default value:
# 20210709 13:32:18.518 TRACE:: Composer(): Loading Assemblies from /content/Lean/Launcher/bin/Debug/
# 20210709 13:32:18.600 TRACE:: Python for .NET Assembly: Python.Runtime, Version=2.0.4.0, Culture=neutral, PublicKeyToken=5000fea6cba702dd
# 20210709 13:32:18.689 TRACE:: Config.Get(): Configuration key not found. Key: data-directory - Using default value: ../../../Data/
# 20210709 13:32:18.691 TRACE:: Config.Get(): Configuration key not found. Key: version-id - Using default value:
# ...

# %% [markdown]
# #Run Python Algorithms
# ###Update the config to run a python algorithm:
# /content/Lean/Launcher/config.json
#
# "algorithm-type-name": "BasicTemplateAlgorithm",
#
# "algorithm-language": "Python",
#
# "algorithm-location": "../../../Algorithm.Python/BasicTemplateAlgorithm.py",

# %%
cd ../../..
# Out:
# /content/Lean

# %% [markdown]
# #Rebuild the project

# %%
from IPython.display import clear_output
# !dotnet build QuantConnect.Lean.sln
clear_output(wait=True )
#Time Elapsed 00:00:07.15
# Out:
# ==Microsoft (R) Build Engine version 16.10.1+2fd48ab73 for .NET
# Copyright (C) Microsoft Corporation. All rights reserved.
#
#   Determining projects to restore...
#   All projects are up-to-date for restore.
#   QuantConnect.Logging -> /content/Lean/Logging/bin/Debug/QuantConnect.Logging.dll
#   SelectedOptimization
#   QuantConnect.Configuration -> /content/Lean/Configuration/bin/Debug/QuantConnect.Configuration.dll
#   SelectedOptimization
#   QuantConnect.Compression -> /content/Lean/Compression/bin/Debug/QuantConnect.Compression.dll
#   SelectedOptimization
#   QuantConnect -> /content/Lean/Common/bin/Debug/QuantConnect.Common.dll
#   SelectedOptimization
#   QuantConnect.Indicators -> /content/Lean/Indicators/bin/Debug/QuantConnect.Indicators.dll
#   SelectedOptimization
#   QuantConnect.Algorithm -> /content/Lean/Algorithm/bin/Debug/QuantConnect.Algorithm.dll
#   QuantConnect.Api -> /content/Lean/Api/bin/Debug/QuantConnect.Api.dll
#   SelectedOptimization
# ...

# %%
cd Launcher/bin/Debug/
# Out:
# /content/Lean/Launcher/bin/Debug

# %%
# !dotnet QuantConnect.Lean.Launcher.dll
# Out:
# =20210709 13:32:55.536 TRACE:: Config.GetValue(): debug-mode - Using default value: False
# 20210709 13:32:55.545 TRACE:: Config.Get(): Configuration key not found. Key: results-destination-folder - Using default value:
# 20210709 13:32:55.546 TRACE:: Config.Get(): Configuration key not found. Key: plugin-directory - Using default value:
# 20210709 13:32:55.549 TRACE:: Config.Get(): Configuration key not found. Key: composer-dll-directory - Using default value:
# 20210709 13:32:55.555 TRACE:: Composer(): Loading Assemblies from /content/Lean/Launcher/bin/Debug/
# 20210709 13:32:55.625 TRACE:: Python for .NET Assembly: Python.Runtime, Version=2.0.4.0, Culture=neutral, PublicKeyToken=5000fea6cba702dd
# 20210709 13:32:55.730 TRACE:: Config.Get(): Configuration key not found. Key: data-directory - Using default value: ../../../Data/
# 20210709 13:32:55.732 TRACE:: Config.Get(): Configuration key not found. Key: version-id - Using default value:
# ...
